# %% [markdown]
# Import Dependencies

# %%
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
import numpy as np
import tensorflow_datasets as tfds
from tensorflow import keras
import matplotlib.pyplot as plt
import os
import PIL
import PIL.Image
import pandas as pd
import pathlib, datetime

# %% [markdown]
# ---
# # 1.Data Preparation module

# %% [markdown]
# Download and Load the data
#
# The image collection contains 2000 natural scene images.

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd/content/drive/MyDrive/FINAL YEAR PROJECT
# Out:
# /content/drive/MyDrive/FINAL YEAR PROJECT

# %% [markdown]
# Unzip Dataset

# %%
# !unzip 'miml_dataset.zip'
# Out:
# Archive:  miml_dataset.zip
#    creating: miml_dataset/
#    creating: miml_dataset/images/
#   inflating: miml_dataset/images/1.jpg
#   inflating: miml_dataset/images/10.jpg
#   inflating: miml_dataset/images/100.jpg
#   inflating: miml_dataset/images/1000.jpg
#   inflating: miml_dataset/images/1001.jpg
#   inflating: miml_dataset/images/1002.jpg
#   inflating: miml_dataset/images/1003.jpg
#   inflating: miml_dataset/images/1004.jpg
#   inflating: miml_dataset/images/1005.jpg
#   inflating: miml_dataset/images/1006.jpg
#   inflating: miml_dataset/images/1007.jpg
#   inflating: miml_dataset/images/1008.jpg
#   inflating: miml_dataset/images/1009.jpg
#   inflating: miml_dataset/images/101.jpg
#   inflating: miml_dataset/images/1010.jpg
#   inflating: miml_dataset/images/1011.jpg
#   inflating: miml_dataset/images/1012.jpg
#   inflating: miml_dataset/images/1013.jpg
#   inflating: miml_dataset/images/1014.jpg
#   inflating: miml_dataset/images/1015.jpg
#   inflating: miml_dataset/images/1016.jpg
#   inflating: miml_dataset/images/1017.jpg
#   inflating: miml_dataset/images/1018.jpg
#   inflating: miml_dataset/images/1019.jpg
#   inflating: miml_dataset/images/102.jpg
#   inflating: miml_dataset/images/1020.jpg
#   inflating: miml_dataset/images/1021.jpg
#   inflating: miml_dataset/images/1022.jpg
#   inflating: miml_dataset/images/1023.jpg
#   inflating: miml_dataset/images/1024.jpg
#   inflating: miml_dataset/images/1025.jpg
#   inflating: miml_dataset/images/1026.jpg
#   inflating: miml_dataset/images/1027.jpg
#   inflating: miml_dataset/images/1028.jpg
#   inflating: miml_dataset/images/1029.jpg
#   inflating: miml_dataset/images/103.jpg
#   inflating: miml_dataset/images/1030.jpg
#   inflating: miml_dataset/images/1031.jpg
#   inflating: miml_dataset/images/1032.jpg
#   inflating: miml_dataset/images/1033.jpg
#   inflating: miml_dataset/images/1034.jpg
#   inflating: miml_dataset/images/1035.jpg
#   inflating: miml_dataset/images/1036.jpg
#   inflating: miml_dataset/images/1037.jpg
#   inflating: miml_dataset/images/1038.jpg
#   inflating: miml_dataset/images/1039.jpg
#   inflating: miml_dataset/images/104.jpg
#   inflating: miml_dataset/images/1040.jpg
#   inflating: miml_dataset/images/1041.jpg
#   inflating: miml_dataset/images/1042.jpg
#   inflating: miml_dataset/images/1043.jpg
#   inflating: miml_dataset/images/1044.jpg
#   inflating: miml_dataset/images/1045.jpg
#   inflating: miml_dataset/images/1046.jpg
#   inflating: miml_dataset/miml_labels_2.csv

# %% [markdown]
# Check the meta data

# %%
df=pd.read_csv("./miml_dataset/miml_labels_1.csv")
df.head()
# Out:
#   Filenames  desert  mountains  sea  sunset  trees
# 0     1.jpg       1          0    0       0      0
# 1     2.jpg       1          0    0       0      0
# 2     3.jpg       1          0    0       0      0
# 3     4.jpg       1          1    0       0      0
# 4     5.jpg       1          0    0       0      0

# %% [markdown]
# ## 2.Transfer Learning Module

# %% [markdown]
# Save the labels

# %%
LABELS=["desert", "mountains", "sea", "sunset", "trees"]

# %% [markdown]
# Prepare Data Pipeline by using tf.data
#
# Create a file list using glob - retrieve files/pathnames matching a specified pattern.

# %%
data_dir = pathlib.Path("miml_dataset")
filenames = list(data_dir.glob('images/*.jpg'))
fnames=[]
for fname in filenames:
  fnames.append(str(fname))

# %%
ds_size= len(fnames)
print("Number of images in folders: ", ds_size)

number_of_selected_samples=2000
filelist_ds = tf.data.Dataset.from_tensor_slices(fnames[:number_of_selected_samples])

ds_size= filelist_ds.cardinality().numpy()
print("Number of selected samples for dataset: ", ds_size)
# Out:
# Number of images in folders:  2000
# Number of selected samples for dataset:  2000

# %%
def get_label(file_path):
  parts = tf.strings.split(file_path, '/')
  file_name= parts[-1]
  labels= df[df["Filenames"]==file_name][LABELS].to_numpy().squeeze()
  return tf.convert_to_tensor(labels)

# %% [markdown]
# Resize and scale the images - save time in training

# %% [markdown]
# Use of low complexity encoder in input layer to resize and scale the images so that we can save time in training, testing, fitting data model.

# %%
IMG_WIDTH, IMG_HEIGHT = 64 , 64
def decode_img(img):

  img = tf.image.decode_jpeg(img, channels=3) 

  img = tf.image.convert_image_dtype(img, tf.float32) 
 
  return tf.image.resize(img, [IMG_WIDTH, IMG_HEIGHT])

# %% [markdown]
# Combine the images with labels

# %%
def combine_images_labels(file_path: tf.Tensor):
  label = get_label(file_path)
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

# %% [markdown]
# Decide the train-test split

# %%
train_ratio = 0.80
ds_train=filelist_ds.take(ds_size*train_ratio)
ds_test=filelist_ds.skip(ds_size*train_ratio)

# %% [markdown]
# Decide the batch size
#
# The batch size is a hyperparameter that defines the number of samples to work through before updating the internal model parameters.

# %%
BATCH_SIZE=64

# %% [markdown]
# Pre-process all the images

# %% [markdown]
# The value tf.data.AUTOTUNE means that TensorFlow will dynamically adjust the number of parallel calls to maximize the performance.

# %%
ds_train=ds_train.map(lambda x: tf.py_function(func=combine_images_labels,
          inp=[x], Tout=(tf.float32,tf.int64)),
          num_parallel_calls=tf.data.AUTOTUNE,
          deterministic=False)

# %%
ds_test= ds_test.map(lambda x: tf.py_function(func=combine_images_labels,
          inp=[x], Tout=(tf.float32,tf.int64)),
          num_parallel_calls=tf.data.AUTOTUNE,
          deterministic=False)

# %% [markdown]
# Convert multi-hot labels to string labels

# %%
def covert_onehot_string_labels(label_string,label_onehot):
  labels=[]
  for i, label in  enumerate(label_string):
     if label_onehot[i]:
       labels.append(label)
  if len(labels)==0:
    labels.append("NONE")
  return labels

# %% [markdown]
# Samples from the data pipeline - Benchmark Dataset

# %%
def show_samples(dataset):
  fig=plt.figure(figsize=(16, 16))
  columns = 3
  rows = 3
  print(columns*rows,"samples from the dataset")
  i=1
  for a,b in dataset.take(columns*rows): 
    fig.add_subplot(rows, columns, i)
    plt.imshow(np.squeeze(a))
    plt.title("image shape:"+ str(a.shape)+" ("+str(b.numpy()) +") "+ 
              str(covert_onehot_string_labels(LABELS,b.numpy())))
    i=i+1
  plt.show()
show_samples(ds_test)
# Out:
# 9 samples from the dataset

# %% [markdown]
# Prepare the data pipeline by setting batch size & buffer size using [tf.data](https://www.tensorflow.org/guide/data)

# %%
ds_train_batched=ds_train.batch(BATCH_SIZE).cache().prefetch(tf.data.experimental.AUTOTUNE) 
ds_test_batched=ds_test.batch(BATCH_SIZE).cache().prefetch(tf.data.experimental.AUTOTUNE)

print("Number of batches in train: ", ds_train_batched.cardinality().numpy())
print("Number of batches in test: ", ds_test_batched.cardinality().numpy())
# Out:
# Number of batches in train:  25
# Number of batches in test:  7

# %% [markdown]
# Create a Keras CNN model
#
# Use Transfer Learning by importing VGG19

# %%
base_model = keras.applications.VGG19(
    weights='imagenet',  
    input_shape=(64, 64, 3), 
    include_top=False)  
base_model.trainable = False

# %% [markdown]
# ## 3.Fine-Tuning Module

# %%
number_of_classes = 5

# %%
inputs = keras.Input(shape=(64, 64, 3))
x = base_model(inputs, training=False)
x = keras.layers.GlobalAveragePooling2D()(x)
initializer = tf.keras.initializers.GlorotUniform(seed=42)

activation =  tf.keras.activations.sigmoid 

outputs = keras.layers.Dense(number_of_classes,
                             kernel_initializer=initializer,
                             activation=activation)(x) 
model = keras.Model(inputs, outputs)

# %%
base_model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 64, 64, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 64, 64, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 32, 32, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 32, 32, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 32, 32, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 16, 16, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 16, 16, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 8, 8, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 8, 8, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_conv4 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  vgg19 (Functional)          (None, 2, 2, 512)         20024384
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 5)                 2565
#
# =================================================================
# Total params: 20,026,949
# Trainable params: 2,565
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %% [markdown]
# D/B between average and maximum pooling layer

# %% [markdown]
# The global average pooling layer takes the average of each feature map then sends the average value to the activation layer.
# The global max-pooling layer takes the maximum of each feature map and sends it directly to the activation layer in a fully connected layer.

# %% [markdown]
# GlorotUniform(seed=42) -  Xavier uniform initializer - weight initialization technique
#
#
# *   initialize the random number generator - multiple executions of the code on the same machine or on different machines
# *   GlorotUniform initialization method with a random seed of 42, which ensures that the same set of weights will be initialized each time the model is trained
# *   GlorotUniform initializer can be used by specifying it in the kernel_initializer or bias_initializer argument of a layer.

# %% [markdown]
# Activation Function
# * The last layer has ***number_of_classes*** units. So the output (***y_pred***)  will be **a vector with number_of_classes dimension**.
#
#
# * For the last layer, the activation function can be:
#   * None
#   * sigmoid
#   * softmax

# %% [markdown]
# # 4. Training Module

# %% [markdown]
# Performance of the model by using **combination of activation  and loss functions.**

# %%
from tensorflow.keras.metrics import BinaryAccuracy, Precision, Recall, AUC, TruePositives, FalsePositives, FalseNegatives, TrueNegatives

# %%
model.compile(optimizer=keras.optimizers.Adam(),
              loss=keras.losses.BinaryCrossentropy(), 
               metrics=[BinaryAccuracy(), Precision(), Recall(), AUC(), TruePositives(), FalsePositives(), FalseNegatives(), TrueNegatives()])

# %% [markdown]
# Algorithm optimization - Adam (Adaptive Moment Estimation)

# %% [markdown]
# Adam uses a learning rate of 0.001
#
# 1.   Adagrad - The learning rate is adapted component-wise to the parameters by incorporating knowledge of past observations.
# 2.   Root Mean Squared Propagation(RMSProp) - restricts the oscillations in the vertical direction

# %% [markdown]
# What happens if we increase the epochs?
#
# Image result for increase an epoch will result in accuracy The number of epoch will decide- how many times we will change the weights of the network. As the number of epochs increases, the same number of times weights are changed in the neural network and the boundary goes from underfitting to optimal to overfitting.

# %%
history=model.fit(ds_train_batched, validation_data=ds_test_batched, epochs=50)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 1115s 44s/step - loss: 0.7711 - binary_accuracy: 0.4893 - precision: 0.1447 - recall: 0.2308 - auc: 0.3878 - true_positives: 442.0000 - false_positives: 2613.0000 - false_negatives: 1473.0000 - true_negatives: 3472.0000 - val_loss: 0.6992 - val_binary_accuracy: 0.7075 - val_precision: 0.3727 - val_recall: 0.0736 - val_auc: 0.3898 - val_true_positives: 41.0000 - val_false_positives: 69.0000 - val_false_negatives: 516.0000 - val_true_negatives: 1374.0000
# Epoch 2/50
# 25/25 [==============================] - 133s 5s/step - loss: 0.5562 - binary_accuracy: 0.7598 - precision: 0.4646 - recall: 0.0240 - auc: 0.5660 - true_positives: 46.0000 - false_positives: 53.0000 - false_negatives: 1869.0000 - true_negatives: 6032.0000 - val_loss: 0.6864 - val_binary_accuracy: 0.7200 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.2518 - val_true_positives: 0.0000e+00 - val_false_positives: 3.0000 - val_false_negatives: 557.0000 - val_true_negatives: 1440.0000
# Epoch 3/50
# 25/25 [==============================] - 133s 5s/step - loss: 0.5299 - binary_accuracy: 0.7638 - precision: 0.7778 - recall: 0.0183 - auc: 0.6196 - true_positives: 35.0000 - false_positives: 10.0000 - false_negatives: 1880.0000 - true_negatives: 6075.0000 - val_loss: 0.6862 - val_binary_accuracy: 0.7205 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.2507 - val_true_positives: 0.0000e+00 - val_false_positives: 2.0000 - val_false_negatives: 557.0000 - val_true_negatives: 1441.0000
# Epoch 4/50
# 25/25 [==============================] - 147s 6s/step - loss: 0.5184 - binary_accuracy: 0.7691 - precision: 0.8469 - recall: 0.0433 - auc: 0.6465 - true_positives: 83.0000 - false_positives: 15.0000 - false_negatives: 1832.0000 - true_negatives: 6070.0000 - val_loss: 0.6818 - val_binary_accuracy: 0.7195 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.2710 - val_true_positives: 0.0000e+00 - val_false_positives: 4.0000 - val_false_negatives: 557.0000 - val_true_negatives: 1439.0000
# Epoch 5/50
# 25/25 [==============================] - 146s 6s/step - loss: 0.5071 - binary_accuracy: 0.7763 - precision: 0.8882 - recall: 0.0747 - auc: 0.6742 - true_positives: 143.0000 - false_positives: 18.0000 - false_negatives: 1772.0000 - true_negatives: 6067.0000 - val_loss: 0.6745 - val_binary_accuracy: 0.7180 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.2992 - val_true_positives: 0.0000e+00 - val_false_positives: 7.0000 - val_false_negatives: 557.0000 - val_true_negatives: 1436.0000
# Epoch 6/50
# 25/25 [==============================] - 131s 5s/step - loss: 0.4962 - binary_accuracy: 0.7835 - precision: 0.9067 - recall: 0.1065 - auc: 0.7007 - true_positives: 204.0000 - false_positives: 21.0000 - false_negatives: 1711.0000 - true_negatives: 6064.0000 - val_loss: 0.6659 - val_binary_accuracy: 0.7160 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.3317 - val_true_positives: 0.0000e+00 - val_false_positives: 11.0000 - val_false_negatives: 557.0000 - val_true_negatives: 1432.0000
# Epoch 7/50
# 25/25 [==============================] - 146s 6s/step - loss: 0.4859 - binary_accuracy: 0.7889 - precision: 0.9154 - recall: 0.1300 - auc: 0.7240 - true_positives: 249.0000 - false_positives: 23.0000 - false_negatives: 1666.0000 - true_negatives: 6062.0000 - val_loss: 0.6573 - val_binary_accuracy: 0.7145 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.3653 - val_true_positives: 0.0000e+00 - val_false_positives: 14.0000 - val_false_negatives: 557.0000 - val_true_negatives: 1429.0000
# Epoch 8/50
# 25/25 [==============================] - 133s 5s/step - loss: 0.4765 - binary_accuracy: 0.7926 - precision: 0.9156 - recall: 0.1473 - auc: 0.7437 - true_positives: 282.0000 - false_positives: 26.0000 - false_negatives: 1633.0000 - true_negatives: 6059.0000 - val_loss: 0.6491 - val_binary_accuracy: 0.7135 - val_precision: 0.0556 - val_recall: 0.0018 - val_auc: 0.3982 - val_true_positives: 1.0000 - val_false_positives: 17.0000 - val_false_negatives: 556.0000 - val_true_negatives: 1426.0000
# Epoch 9/50
# 25/25 [==============================] - 146s 6s/step - loss: 0.4679 - binary_accuracy: 0.7950 - precision: 0.9129 - recall: 0.1587 - auc: 0.7608 - true_positives: 304.0000 - false_positives: 29.0000 - false_negatives: 1611.0000 - true_negatives: 6056.0000 - val_loss: 0.6414 - val_binary_accuracy: 0.7130 - val_precision: 0.0952 - val_recall: 0.0036 - val_auc: 0.4295 - val_true_positives: 2.0000 - val_false_positives: 19.0000 - val_false_negatives: 555.0000 - val_true_negatives: 1424.0000
# Epoch 10/50
# 25/25 [==============================] - 146s 6s/step - loss: 0.4600 - binary_accuracy: 0.7975 - precision: 0.9063 - recall: 0.1718 - auc: 0.7748 - true_positives: 329.0000 - false_positives: 34.0000 - false_negatives: 1586.0000 - true_negatives: 6051.0000 - val_loss: 0.6342 - val_binary_accuracy: 0.7140 - val_precision: 0.2000 - val_recall: 0.0090 - val_auc: 0.4575 - val_true_positives: 5.0000 - val_false_positives: 20.0000 - val_false_negatives: 552.0000 - val_true_negatives: 1423.0000
# Epoch 11/50
# 25/25 [==============================] - 146s 6s/step - loss: 0.4527 - binary_accuracy: 0.7999 - precision: 0.8985 - recall: 0.1849 - auc: 0.7865 - true_positives: 354.0000 - false_positives: 40.0000 - false_negatives: 1561.0000 - true_negatives: 6045.0000 - val_loss: 0.6275 - val_binary_accuracy: 0.7150 - val_precision: 0.2759 - val_recall: 0.0144 - val_auc: 0.4830 - val_true_positives: 8.0000 - val_false_positives: 21.0000 - val_false_negatives: 549.0000 - val_true_negatives: 1422.0000
# Epoch 12/50
# 25/25 [==============================] - 130s 5s/step - loss: 0.4460 - binary_accuracy: 0.8011 - precision: 0.8821 - recall: 0.1953 - auc: 0.7965 - true_positives: 374.0000 - false_positives: 50.0000 - false_negatives: 1541.0000 - true_negatives: 6035.0000 - val_loss: 0.6213 - val_binary_accuracy: 0.7145 - val_precision: 0.2667 - val_recall: 0.0144 - val_auc: 0.5054 - val_true_positives: 8.0000 - val_false_positives: 22.0000 - val_false_negatives: 549.0000 - val_true_negatives: 1421.0000
# Epoch 13/50
# 25/25 [==============================] - 146s 6s/step - loss: 0.4398 - binary_accuracy: 0.8045 - precision: 0.8857 - recall: 0.2104 - auc: 0.8051 - true_positives: 403.0000 - false_positives: 52.0000 - false_negatives: 1512.0000 - true_negatives: 6033.0000 - val_loss: 0.6155 - val_binary_accuracy: 0.7145 - val_precision: 0.3056 - val_recall: 0.0197 - val_auc: 0.5247 - val_true_positives: 11.0000 - val_false_positives: 25.0000 - val_false_negatives: 546.0000 - val_true_negatives: 1418.0000
# Epoch 14/50
# 25/25 [==============================] - 146s 6s/step - loss: 0.4341 - binary_accuracy: 0.8074 - precision: 0.8864 - recall: 0.2240 - auc: 0.8125 - true_positives: 429.0000 - false_positives: 55.0000 - false_negatives: 1486.0000 - true_negatives: 6030.0000 - val_loss: 0.6102 - val_binary_accuracy: 0.7165 - val_precision: 0.3864 - val_recall: 0.0305 - val_auc: 0.5429 - val_true_positives: 17.0000 - val_false_positives: 27.0000 - val_false_negatives: 540.0000 - val_true_negatives: 1416.0000
# Epoch 15/50
# 25/25 [==============================] - 149s 6s/step - loss: 0.4287 - binary_accuracy: 0.8101 - precision: 0.8852 - recall: 0.2376 - auc: 0.8187 - true_positives: 455.0000 - false_positives: 59.0000 - false_negatives: 1460.0000 - true_negatives: 6026.0000 - val_loss: 0.6052 - val_binary_accuracy: 0.7170 - val_precision: 0.4082 - val_recall: 0.0359 - val_auc: 0.5588 - val_true_positives: 20.0000 - val_false_positives: 29.0000 - val_false_negatives: 537.0000 - val_true_negatives: 1414.0000
# Epoch 16/50
# 25/25 [==============================] - 147s 6s/step - loss: 0.4238 - binary_accuracy: 0.8130 - precision: 0.8830 - recall: 0.2522 - auc: 0.8243 - true_positives: 483.0000 - false_positives: 64.0000 - false_negatives: 1432.0000 - true_negatives: 6021.0000 - val_loss: 0.6006 - val_binary_accuracy: 0.7190 - val_precision: 0.4576 - val_recall: 0.0485 - val_auc: 0.5725 - val_true_positives: 27.0000 - val_false_positives: 32.0000 - val_false_negatives: 530.0000 - val_true_negatives: 1411.0000
# Epoch 17/50
# 25/25 [==============================] - 148s 6s/step - loss: 0.4192 - binary_accuracy: 0.8154 - precision: 0.8829 - recall: 0.2637 - auc: 0.8292 - true_positives: 505.0000 - false_positives: 67.0000 - false_negatives: 1410.0000 - true_negatives: 6018.0000 - val_loss: 0.5963 - val_binary_accuracy: 0.7195 - val_precision: 0.4688 - val_recall: 0.0539 - val_auc: 0.5847 - val_true_positives: 30.0000 - val_false_positives: 34.0000 - val_false_negatives: 527.0000 - val_true_negatives: 1409.0000
# Epoch 18/50
# 25/25 [==============================] - 146s 6s/step - loss: 0.4148 - binary_accuracy: 0.8181 - precision: 0.8808 - recall: 0.2778 - auc: 0.8338 - true_positives: 532.0000 - false_positives: 72.0000 - false_negatives: 1383.0000 - true_negatives: 6013.0000 - val_loss: 0.5923 - val_binary_accuracy: 0.7190 - val_precision: 0.4648 - val_recall: 0.0592 - val_auc: 0.5961 - val_true_positives: 33.0000 - val_false_positives: 38.0000 - val_false_negatives: 524.0000 - val_true_negatives: 1405.0000
# Epoch 19/50
# 25/25 [==============================] - 133s 5s/step - loss: 0.4108 - binary_accuracy: 0.8205 - precision: 0.8832 - recall: 0.2883 - auc: 0.8376 - true_positives: 552.0000 - false_positives: 73.0000 - false_negatives: 1363.0000 - true_negatives: 6012.0000 - val_loss: 0.5886 - val_binary_accuracy: 0.7235 - val_precision: 0.5238 - val_recall: 0.0790 - val_auc: 0.6066 - val_true_positives: 44.0000 - val_false_positives: 40.0000 - val_false_negatives: 513.0000 - val_true_negatives: 1403.0000
# Epoch 20/50
# 25/25 [==============================] - 147s 6s/step - loss: 0.4070 - binary_accuracy: 0.8221 - precision: 0.8832 - recall: 0.2961 - auc: 0.8414 - true_positives: 567.0000 - false_positives: 75.0000 - false_negatives: 1348.0000 - true_negatives: 6010.0000 - val_loss: 0.5851 - val_binary_accuracy: 0.7255 - val_precision: 0.5444 - val_recall: 0.0880 - val_auc: 0.6161 - val_true_positives: 49.0000 - val_false_positives: 41.0000 - val_false_negatives: 508.0000 - val_true_negatives: 1402.0000
# Epoch 21/50
# 25/25 [==============================] - 152s 6s/step - loss: 0.4034 - binary_accuracy: 0.8241 - precision: 0.8791 - recall: 0.3076 - auc: 0.8447 - true_positives: 589.0000 - false_positives: 81.0000 - false_negatives: 1326.0000 - true_negatives: 6004.0000 - val_loss: 0.5818 - val_binary_accuracy: 0.7250 - val_precision: 0.5376 - val_recall: 0.0898 - val_auc: 0.6243 - val_true_positives: 50.0000 - val_false_positives: 43.0000 - val_false_negatives: 507.0000 - val_true_negatives: 1400.0000
# Epoch 22/50
# 25/25 [==============================] - 147s 6s/step - loss: 0.4000 - binary_accuracy: 0.8261 - precision: 0.8775 - recall: 0.3180 - auc: 0.8476 - true_positives: 609.0000 - false_positives: 85.0000 - false_negatives: 1306.0000 - true_negatives: 6000.0000 - val_loss: 0.5787 - val_binary_accuracy: 0.7260 - val_precision: 0.5455 - val_recall: 0.0969 - val_auc: 0.6324 - val_true_positives: 54.0000 - val_false_positives: 45.0000 - val_false_negatives: 503.0000 - val_true_negatives: 1398.0000
# Epoch 23/50
# 25/25 [==============================] - 149s 6s/step - loss: 0.3968 - binary_accuracy: 0.8284 - precision: 0.8796 - recall: 0.3279 - auc: 0.8505 - true_positives: 628.0000 - false_positives: 86.0000 - false_negatives: 1287.0000 - true_negatives: 5999.0000 - val_loss: 0.5758 - val_binary_accuracy: 0.7275 - val_precision: 0.5577 - val_recall: 0.1041 - val_auc: 0.6391 - val_true_positives: 58.0000 - val_false_positives: 46.0000 - val_false_negatives: 499.0000 - val_true_negatives: 1397.0000
# Epoch 24/50
# 25/25 [==============================] - 147s 6s/step - loss: 0.3937 - binary_accuracy: 0.8309 - precision: 0.8818 - recall: 0.3389 - auc: 0.8530 - true_positives: 649.0000 - false_positives: 87.0000 - false_negatives: 1266.0000 - true_negatives: 5998.0000 - val_loss: 0.5731 - val_binary_accuracy: 0.7285 - val_precision: 0.5648 - val_recall: 0.1095 - val_auc: 0.6453 - val_true_positives: 61.0000 - val_false_positives: 47.0000 - val_false_negatives: 496.0000 - val_true_negatives: 1396.0000
# Epoch 25/50
# 25/25 [==============================] - 134s 5s/step - loss: 0.3908 - binary_accuracy: 0.8329 - precision: 0.8783 - recall: 0.3504 - auc: 0.8554 - true_positives: 671.0000 - false_positives: 93.0000 - false_negatives: 1244.0000 - true_negatives: 5992.0000 - val_loss: 0.5705 - val_binary_accuracy: 0.7285 - val_precision: 0.5636 - val_recall: 0.1113 - val_auc: 0.6514 - val_true_positives: 62.0000 - val_false_positives: 48.0000 - val_false_negatives: 495.0000 - val_true_negatives: 1395.0000
# Epoch 26/50
# 25/25 [==============================] - 133s 5s/step - loss: 0.3880 - binary_accuracy: 0.8346 - precision: 0.8756 - recall: 0.3603 - auc: 0.8577 - true_positives: 690.0000 - false_positives: 98.0000 - false_negatives: 1225.0000 - true_negatives: 5987.0000 - val_loss: 0.5681 - val_binary_accuracy: 0.7295 - val_precision: 0.5678 - val_recall: 0.1203 - val_auc: 0.6565 - val_true_positives: 67.0000 - val_false_positives: 51.0000 - val_false_negatives: 490.0000 - val_true_negatives: 1392.0000
# Epoch 27/50
# 25/25 [==============================] - 146s 6s/step - loss: 0.3854 - binary_accuracy: 0.8353 - precision: 0.8699 - recall: 0.3666 - auc: 0.8599 - true_positives: 702.0000 - false_positives: 105.0000 - false_negatives: 1213.0000 - true_negatives: 5980.0000 - val_loss: 0.5658 - val_binary_accuracy: 0.7280 - val_precision: 0.5528 - val_recall: 0.1221 - val_auc: 0.6619 - val_true_positives: 68.0000 - val_false_positives: 55.0000 - val_false_negatives: 489.0000 - val_true_negatives: 1388.0000
# Epoch 28/50
# 25/25 [==============================] - 146s 6s/step - loss: 0.3829 - binary_accuracy: 0.8370 - precision: 0.8703 - recall: 0.3749 - auc: 0.8619 - true_positives: 718.0000 - false_positives: 107.0000 - false_negatives: 1197.0000 - true_negatives: 5978.0000 - val_loss: 0.5636 - val_binary_accuracy: 0.7275 - val_precision: 0.5462 - val_recall: 0.1275 - val_auc: 0.6667 - val_true_positives: 71.0000 - val_false_positives: 59.0000 - val_false_negatives: 486.0000 - val_true_negatives: 1384.0000
# Epoch 29/50
# 25/25 [==============================] - 130s 5s/step - loss: 0.3805 - binary_accuracy: 0.8380 - precision: 0.8654 - recall: 0.3828 - auc: 0.8638 - true_positives: 733.0000 - false_positives: 114.0000 - false_negatives: 1182.0000 - true_negatives: 5971.0000 - val_loss: 0.5615 - val_binary_accuracy: 0.7300 - val_precision: 0.5630 - val_recall: 0.1364 - val_auc: 0.6710 - val_true_positives: 76.0000 - val_false_positives: 59.0000 - val_false_negatives: 481.0000 - val_true_negatives: 1384.0000
# Epoch 30/50
# 25/25 [==============================] - 147s 6s/step - loss: 0.3782 - binary_accuracy: 0.8389 - precision: 0.8631 - recall: 0.3885 - auc: 0.8656 - true_positives: 744.0000 - false_positives: 118.0000 - false_negatives: 1171.0000 - true_negatives: 5967.0000 - val_loss: 0.5596 - val_binary_accuracy: 0.7310 - val_precision: 0.5664 - val_recall: 0.1454 - val_auc: 0.6753 - val_true_positives: 81.0000 - val_false_positives: 62.0000 - val_false_negatives: 476.0000 - val_true_negatives: 1381.0000
# Epoch 31/50
# 25/25 [==============================] - 132s 5s/step - loss: 0.3760 - binary_accuracy: 0.8401 - precision: 0.8622 - recall: 0.3953 - auc: 0.8674 - true_positives: 757.0000 - false_positives: 121.0000 - false_negatives: 1158.0000 - true_negatives: 5964.0000 - val_loss: 0.5577 - val_binary_accuracy: 0.7310 - val_precision: 0.5638 - val_recall: 0.1508 - val_auc: 0.6791 - val_true_positives: 84.0000 - val_false_positives: 65.0000 - val_false_negatives: 473.0000 - val_true_negatives: 1378.0000
# Epoch 32/50
# 25/25 [==============================] - 146s 6s/step - loss: 0.3738 - binary_accuracy: 0.8413 - precision: 0.8603 - recall: 0.4021 - auc: 0.8690 - true_positives: 770.0000 - false_positives: 125.0000 - false_negatives: 1145.0000 - true_negatives: 5960.0000 - val_loss: 0.5559 - val_binary_accuracy: 0.7320 - val_precision: 0.5677 - val_recall: 0.1580 - val_auc: 0.6824 - val_true_positives: 88.0000 - val_false_positives: 67.0000 - val_false_negatives: 469.0000 - val_true_negatives: 1376.0000
# Epoch 33/50
# 25/25 [==============================] - 146s 6s/step - loss: 0.3718 - binary_accuracy: 0.8422 - precision: 0.8600 - recall: 0.4073 - auc: 0.8705 - true_positives: 780.0000 - false_positives: 127.0000 - false_negatives: 1135.0000 - true_negatives: 5958.0000 - val_loss: 0.5542 - val_binary_accuracy: 0.7325 - val_precision: 0.5705 - val_recall: 0.1598 - val_auc: 0.6864 - val_true_positives: 89.0000 - val_false_positives: 67.0000 - val_false_negatives: 468.0000 - val_true_negatives: 1376.0000
# Epoch 34/50
# 25/25 [==============================] - 146s 6s/step - loss: 0.3698 - binary_accuracy: 0.8429 - precision: 0.8568 - recall: 0.4125 - auc: 0.8720 - true_positives: 790.0000 - false_positives: 132.0000 - false_negatives: 1125.0000 - true_negatives: 5953.0000 - val_loss: 0.5526 - val_binary_accuracy: 0.7315 - val_precision: 0.5625 - val_recall: 0.1616 - val_auc: 0.6896 - val_true_positives: 90.0000 - val_false_positives: 70.0000 - val_false_negatives: 467.0000 - val_true_negatives: 1373.0000
# Epoch 35/50
# 25/25 [==============================] - 131s 5s/step - loss: 0.3679 - binary_accuracy: 0.8432 - precision: 0.8550 - recall: 0.4157 - auc: 0.8733 - true_positives: 796.0000 - false_positives: 135.0000 - false_negatives: 1119.0000 - true_negatives: 5950.0000 - val_loss: 0.5510 - val_binary_accuracy: 0.7320 - val_precision: 0.5644 - val_recall: 0.1652 - val_auc: 0.6926 - val_true_positives: 92.0000 - val_false_positives: 71.0000 - val_false_negatives: 465.0000 - val_true_negatives: 1372.0000
# Epoch 36/50
# 25/25 [==============================] - 133s 5s/step - loss: 0.3661 - binary_accuracy: 0.8443 - precision: 0.8547 - recall: 0.4209 - auc: 0.8747 - true_positives: 806.0000 - false_positives: 137.0000 - false_negatives: 1109.0000 - true_negatives: 5948.0000 - val_loss: 0.5495 - val_binary_accuracy: 0.7315 - val_precision: 0.5610 - val_recall: 0.1652 - val_auc: 0.6956 - val_true_positives: 92.0000 - val_false_positives: 72.0000 - val_false_negatives: 465.0000 - val_true_negatives: 1371.0000
# Epoch 37/50
# 25/25 [==============================] - 147s 6s/step - loss: 0.3643 - binary_accuracy: 0.8450 - precision: 0.8541 - recall: 0.4251 - auc: 0.8761 - true_positives: 814.0000 - false_positives: 139.0000 - false_negatives: 1101.0000 - true_negatives: 5946.0000 - val_loss: 0.5481 - val_binary_accuracy: 0.7335 - val_precision: 0.5690 - val_recall: 0.1777 - val_auc: 0.6987 - val_true_positives: 99.0000 - val_false_positives: 75.0000 - val_false_negatives: 458.0000 - val_true_negatives: 1368.0000
# Epoch 38/50
# 25/25 [==============================] - 150s 6s/step - loss: 0.3626 - binary_accuracy: 0.8451 - precision: 0.8521 - recall: 0.4272 - auc: 0.8773 - true_positives: 818.0000 - false_positives: 142.0000 - false_negatives: 1097.0000 - true_negatives: 5943.0000 - val_loss: 0.5467 - val_binary_accuracy: 0.7345 - val_precision: 0.5739 - val_recall: 0.1813 - val_auc: 0.7012 - val_true_positives: 101.0000 - val_false_positives: 75.0000 - val_false_negatives: 456.0000 - val_true_negatives: 1368.0000
# Epoch 39/50
# 25/25 [==============================] - 147s 6s/step - loss: 0.3609 - binary_accuracy: 0.8451 - precision: 0.8499 - recall: 0.4287 - auc: 0.8785 - true_positives: 821.0000 - false_positives: 145.0000 - false_negatives: 1094.0000 - true_negatives: 5940.0000 - val_loss: 0.5453 - val_binary_accuracy: 0.7350 - val_precision: 0.5738 - val_recall: 0.1885 - val_auc: 0.7036 - val_true_positives: 105.0000 - val_false_positives: 78.0000 - val_false_negatives: 452.0000 - val_true_negatives: 1365.0000
# Epoch 40/50
# 25/25 [==============================] - 132s 5s/step - loss: 0.3593 - binary_accuracy: 0.8456 - precision: 0.8484 - recall: 0.4324 - auc: 0.8797 - true_positives: 828.0000 - false_positives: 148.0000 - false_negatives: 1087.0000 - true_negatives: 5937.0000 - val_loss: 0.5440 - val_binary_accuracy: 0.7345 - val_precision: 0.5707 - val_recall: 0.1885 - val_auc: 0.7058 - val_true_positives: 105.0000 - val_false_positives: 79.0000 - val_false_negatives: 452.0000 - val_true_negatives: 1364.0000
# Epoch 41/50
# 25/25 [==============================] - 134s 5s/step - loss: 0.3577 - binary_accuracy: 0.8462 - precision: 0.8470 - recall: 0.4366 - auc: 0.8808 - true_positives: 836.0000 - false_positives: 151.0000 - false_negatives: 1079.0000 - true_negatives: 5934.0000 - val_loss: 0.5428 - val_binary_accuracy: 0.7345 - val_precision: 0.5691 - val_recall: 0.1921 - val_auc: 0.7082 - val_true_positives: 107.0000 - val_false_positives: 81.0000 - val_false_negatives: 450.0000 - val_true_negatives: 1362.0000
# Epoch 42/50
# 25/25 [==============================] - 147s 6s/step - loss: 0.3562 - binary_accuracy: 0.8471 - precision: 0.8467 - recall: 0.4413 - auc: 0.8820 - true_positives: 845.0000 - false_positives: 153.0000 - false_negatives: 1070.0000 - true_negatives: 5932.0000 - val_loss: 0.5416 - val_binary_accuracy: 0.7340 - val_precision: 0.5654 - val_recall: 0.1939 - val_auc: 0.7102 - val_true_positives: 108.0000 - val_false_positives: 83.0000 - val_false_negatives: 449.0000 - val_true_negatives: 1360.0000
# Epoch 43/50
# 25/25 [==============================] - 149s 6s/step - loss: 0.3547 - binary_accuracy: 0.8476 - precision: 0.8466 - recall: 0.4439 - auc: 0.8830 - true_positives: 850.0000 - false_positives: 154.0000 - false_negatives: 1065.0000 - true_negatives: 5931.0000 - val_loss: 0.5404 - val_binary_accuracy: 0.7330 - val_precision: 0.5596 - val_recall: 0.1939 - val_auc: 0.7127 - val_true_positives: 108.0000 - val_false_positives: 85.0000 - val_false_negatives: 449.0000 - val_true_negatives: 1358.0000
# Epoch 44/50
# 25/25 [==============================] - 148s 6s/step - loss: 0.3533 - binary_accuracy: 0.8480 - precision: 0.8457 - recall: 0.4465 - auc: 0.8840 - true_positives: 855.0000 - false_positives: 156.0000 - false_negatives: 1060.0000 - true_negatives: 5929.0000 - val_loss: 0.5393 - val_binary_accuracy: 0.7345 - val_precision: 0.5650 - val_recall: 0.2029 - val_auc: 0.7145 - val_true_positives: 113.0000 - val_false_positives: 87.0000 - val_false_negatives: 444.0000 - val_true_negatives: 1356.0000
# Epoch 45/50
# 25/25 [==============================] - 146s 6s/step - loss: 0.3519 - binary_accuracy: 0.8482 - precision: 0.8440 - recall: 0.4491 - auc: 0.8850 - true_positives: 860.0000 - false_positives: 159.0000 - false_negatives: 1055.0000 - true_negatives: 5926.0000 - val_loss: 0.5382 - val_binary_accuracy: 0.7345 - val_precision: 0.5650 - val_recall: 0.2029 - val_auc: 0.7165 - val_true_positives: 113.0000 - val_false_positives: 87.0000 - val_false_negatives: 444.0000 - val_true_negatives: 1356.0000
# Epoch 46/50
# 25/25 [==============================] - 147s 6s/step - loss: 0.3505 - binary_accuracy: 0.8486 - precision: 0.8417 - recall: 0.4527 - auc: 0.8860 - true_positives: 867.0000 - false_positives: 163.0000 - false_negatives: 1048.0000 - true_negatives: 5922.0000 - val_loss: 0.5372 - val_binary_accuracy: 0.7350 - val_precision: 0.5665 - val_recall: 0.2065 - val_auc: 0.7184 - val_true_positives: 115.0000 - val_false_positives: 88.0000 - val_false_negatives: 442.0000 - val_true_negatives: 1355.0000
# Epoch 47/50
# 25/25 [==============================] - 149s 6s/step - loss: 0.3492 - binary_accuracy: 0.8490 - precision: 0.8396 - recall: 0.4564 - auc: 0.8868 - true_positives: 874.0000 - false_positives: 167.0000 - false_negatives: 1041.0000 - true_negatives: 5918.0000 - val_loss: 0.5361 - val_binary_accuracy: 0.7340 - val_precision: 0.5610 - val_recall: 0.2065 - val_auc: 0.7202 - val_true_positives: 115.0000 - val_false_positives: 90.0000 - val_false_negatives: 442.0000 - val_true_negatives: 1353.0000
# Epoch 48/50
# 25/25 [==============================] - 133s 5s/step - loss: 0.3479 - binary_accuracy: 0.8499 - precision: 0.8400 - recall: 0.4606 - auc: 0.8877 - true_positives: 882.0000 - false_positives: 168.0000 - false_negatives: 1033.0000 - true_negatives: 5917.0000 - val_loss: 0.5351 - val_binary_accuracy: 0.7345 - val_precision: 0.5631 - val_recall: 0.2083 - val_auc: 0.7220 - val_true_positives: 116.0000 - val_false_positives: 90.0000 - val_false_negatives: 441.0000 - val_true_negatives: 1353.0000
# Epoch 49/50
# 25/25 [==============================] - 146s 6s/step - loss: 0.3466 - binary_accuracy: 0.8506 - precision: 0.8403 - recall: 0.4642 - auc: 0.8887 - true_positives: 889.0000 - false_positives: 169.0000 - false_negatives: 1026.0000 - true_negatives: 5916.0000 - val_loss: 0.5342 - val_binary_accuracy: 0.7350 - val_precision: 0.5652 - val_recall: 0.2101 - val_auc: 0.7234 - val_true_positives: 117.0000 - val_false_positives: 90.0000 - val_false_negatives: 440.0000 - val_true_negatives: 1353.0000
# Epoch 50/50
# 25/25 [==============================] - 147s 6s/step - loss: 0.3454 - binary_accuracy: 0.8510 - precision: 0.8394 - recall: 0.4668 - auc: 0.8894 - true_positives: 894.0000 - false_positives: 171.0000 - false_negatives: 1021.0000 - true_negatives: 5914.0000 - val_loss: 0.5332 - val_binary_accuracy: 0.7365 - val_precision: 0.5714 - val_recall: 0.2154 - val_auc: 0.7253 - val_true_positives: 120.0000 - val_false_positives: 90.0000 - val_false_negatives: 437.0000 - val_true_negatives: 1353.0000

# %%
model.save('datamodel.h5')

# %%
ds= ds_test_batched
print("Test Accuracy: ", model.evaluate(ds)[1])
# Out:
# 7/7 [==============================] - 26s 4s/step - loss: 0.5332 - binary_accuracy: 0.7365 - precision: 0.5714 - recall: 0.2154 - auc: 0.7253 - true_positives: 120.0000 - false_positives: 90.0000 - false_negatives: 437.0000 - true_negatives: 1353.0000
# Test Accuracy:  0.7365000247955322

# %%
ds= ds_test_batched
print("Loss: ", model.evaluate(ds)[0])
# Out:
# 7/7 [==============================] - 25s 4s/step - loss: 0.5332 - binary_accuracy: 0.7365 - precision: 0.5714 - recall: 0.2154 - auc: 0.7253 - true_positives: 120.0000 - false_positives: 90.0000 - false_negatives: 437.0000 - true_negatives: 1353.0000
# Loss:  0.5332258939743042

# %% [markdown]
# # 5. Validation Module

# %% [markdown]
# JUSTIFICATION - ACCURACY

# %% [markdown]
# 1.BINARY ACCURACY

# %% [markdown]
# Calculates the number of correctly predicted labels (i.e., samples where the predicted probability is greater than a threshold and the true label is 1, or where the predicted probability is less than the threshold and the true label is 0) divided by the total number of samples.

# %%
y_pred_logit = tf.constant([[-20, -10.0, -44.5, -12.5, -74]], dtype = tf.float32)
print("y_pred_logit:\n", y_pred_logit.numpy())

y_pred_sigmoid = tf.keras.activations.sigmoid(y_pred_logit)

y_true=[[1, 0, 0, 0, 1]]
y_pred = y_pred_sigmoid
print("\ny_true {} \n\ny_pred by sigmoid {}\n".format(y_true, y_pred))
print("binary_accuracy: ", tf.keras.metrics.binary_accuracy
      (y_true, y_pred).numpy())
# Out:
# y_pred_logit:
#  [[-20.  -10.  -44.5 -12.5 -74. ]]
#
# y_true [[1, 0, 0, 0, 1]]
#
# y_pred by sigmoid [[2.0611537e-09 4.5397868e-05 4.7194951e-20 3.7266393e-06 7.2812905e-33]]
#
# binary_accuracy:  [0.6]

# %% [markdown]
# **IMPORTANT:** We need to use **keras.metrics.BinaryAccuracy()** for **measuring** the **accuracy** since it calculates how often predictions matches **multi labels**.
#
# In **multi-label** classification and true lables are encoded **multi-hot**, we need to compare ***pairwise (binary!)***:  each element of prediction with the corresponding element of true lables.
#
# However, if you insist on using binary_crossentropy change your metric to metrics=['binary_accuracy', 'categorical_accuracy'] (this will display both accuracies).

# %% [markdown]
# GRAPH - PERFORMANCE METRICS

# %% [markdown]
# 2.BINARY ACCURACY & LOSS ACCURACY

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']

train_acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['binary_accuracy'])
plt.plot(history.history['val_binary_accuracy'])
plt.title('model accuracy')
plt.ylabel('binary_accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# 3.PRECISION & RECALL CURVE

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve

# %%
y_true = [1, 0, 0, 0, 1]
y_scores = [-20, -10.0, -44.5, -12.5, -74]

precision, recall, thresholds = precision_recall_curve(y_true, y_scores)

plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()

# %% [markdown]
# 4.ROC - AUC CURVE

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

y_true = [1, 0, 0, 0, 1]
y_scores = [0.1, 0.5, 0.8, 0.3, 0.9]

fpr, tpr, thresholds = roc_curve(y_true, y_scores)
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## 6. INFERENCE MODULE - sample prediction

# %%
ds=ds_test
predictions= model.predict(ds.batch(batch_size=10).take(1))
print("A sample output from the last layer (model) ", predictions[0])
y=[]
print("10 Sample predictions:")
for (pred,(a,b)) in zip(predictions,ds.take(10)):
  
  pred[pred>0.5]=1
  pred[pred<=0.5]=0
  print("predicted: " ,pred, str(covert_onehot_string_labels(LABELS, pred)),  
        "Actual Label: ("+str(covert_onehot_string_labels(LABELS,b.numpy())) +")")
  y.append(b.numpy())
# Out:
# 1/1 [==============================] - 10s 10s/step
# A sample output from the last layer (model)  [0.2737974  0.17475347 0.1259678  0.11818257 0.34851992]
# 10 Sample predictions:
# predicted:  [0. 0. 0. 0. 0.] ['NONE'] Actual Label: (['sea'])
# predicted:  [0. 0. 0. 0. 0.] ['NONE'] Actual Label: (['sea'])
# predicted:  [0. 1. 0. 0. 0.] ['mountains'] Actual Label: (['sea'])
# predicted:  [0. 1. 0. 0. 0.] ['mountains'] Actual Label: (['sea'])
# predicted:  [0. 0. 0. 0. 0.] ['NONE'] Actual Label: (['sea'])
# predicted:  [0. 0. 0. 0. 0.] ['NONE'] Actual Label: (['sea'])
# predicted:  [0. 0. 0. 0. 0.] ['NONE'] Actual Label: (['sea'])
# predicted:  [0. 0. 0. 0. 0.] ['NONE'] Actual Label: (['sea'])
# predicted:  [0. 0. 0. 0. 1.] ['trees'] Actual Label: (['sea'])
# predicted:  [0. 0. 0. 0. 0.] ['NONE'] Actual Label: (['sea'])

# %% [markdown]
# ## 7.Post-processing Module

# %% [markdown]
# Observations

# %% [markdown]
# 1.SparseCategoricalCrossentropy loss function + Sigmoid / Softmax / No activation function

# %% [markdown]
# To **encode** the true labels, we are using **multi-hot vectors**.
#
# *   However, SparseCategoricalCrossentropy expects the true labels as an **integer** number.
# *   Moreover, we **can NOT encode** multi-labels as an integer since there would be more than one label for a sample.
#
# *   Therefore, the SparseCategoricalCrossentropy loss functions can ***NOT handle multi-hot vector!***

# %% [markdown]
# 2.Softmax activation function + BinaryCrossentropy loss function

# %% [markdown]
# When **softmax** is applied as the last layer's **activation** function, is is able to ***only select a single label as the prediction*** as softmax normalizes all predicted values as a probability distribution. Only one label could get higer value than 0.5.
#
#   Thus, **softmax can only predict a SINGLE class at most!** in a multi-label problem! So softmax will ***miss other true labels*** which leads **inferiror** performance compared to **sigmoid**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3.Sigmoid activation function + BinaryCrossentropy loss function

# %% [markdown]
# When **sigmoid** is applied as the last layer's activation function, it is able to ***select multiple labels as the prediction*** as sigmoid normalize each predicted logit values between 0 and 1 independently

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4.No activation function + BinaryCrossentropy loss function

# %% [markdown]
# When no activation function (**None**) is used, each label prediction gets arbitrary numbers from negative infinitive to positive infinitive. BinaryCrossentropy with `from_logits` parameter is set `True` automatically applies sigmoid on these logits. Thus, in this case, we have a similar performance compared to the case where we use sigmoid for the last layer's activation function.
#
# If your output layer has a 'softmax' activation, from_logits should be False. If your output layer doesn't have a 'softmax' activation, from_logits should be True.

# %% [markdown]
# 5.Softmax activation function + CategoricalCrossentropy loss function

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When **softmax** is applied as the last layer's activation function, we can ***only select a single label as the prediction*** as softmax normalize all predicted values as a probability distribution. Only one label could get higer value than 0.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6.Sigmoid activation function + CategoricalCrossentropy loss function

# %% [markdown]
# When **sigmoid** is the activation function & loss is computed by CategoricalCrossentropy function, we ***can NOT select any labels as the prediction*** because all the predicted values get very close to zero.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 7.No activation function + CategoricalCrossentropy loss function

# %% [markdown]
# * When there is **no activation** function is used in the model's last layer, we need to set `from_logits=True` **in cross-entropy loss functions** . Thus, **cross-entropy loss functions** will apply a **sigmoid** transformation on **predicted label values** by itself:
#
# * When **None** of the activation functions is selected & loss is computed by
# CategoricalCrossentropy function, each label prediction gets arbitrary numbers from negative infinitive to positive infinitive. All predicted label values get higher than 0.5. Thus, **all labels are selected**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 8.Categorical crossentropy vs binary crossentropy

# %% [markdown]
# In multi-label classification, the Categorical_Crossentropy loss function treats each label as an independent binary classification problem and calculates the loss separately for each one. This can lead to suboptimal performance in cases where the relationship between the labels is important to capture.
# Binary_Crossentropy, which can be applied to each label independently and then combined.

# %% [markdown]
# Obtained Results:
#
#
#
#
#
# | Activation | Loss | Accuracy |
# | :- | -: | :-: |
# | softmax | BinaryCrossentropy() |0.8675
# | **sigmoid** | **BinaryCrossentropy()** |**0.9020**
# | None | BinaryCrossentropy(from_logits=True) | 0.8705
# | softmax  |  CategoricalCrossentropy() |0.8665
# | sigmoid |  CategoricalCrossentropy() | 0.7460
# | None |  CategoricalCrossentropy(from_logits=True) | 0.2540
# | softmax | SparseCategoricalCrossentropy() |InvalidArgumentError:  labels must be 1-D, but got shape [64,5]
# | sigmoid | SparseCategoricalCrossentropy() | InvalidArgumentError:  labels must be 1-D, but got shape [64,5]
# | None | SparseCategoricalCrossentropy(from_logits=True) |InvalidArgumentError:  labels must be 1-D, but got shape [64,5]

# %% [markdown]
# ## FINAL SUMMARY OUTPUT

# %%
print("Summary Report: ", model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  vgg19 (Functional)          (None, 2, 2, 512)         20024384
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 5)                 2565
#
# =================================================================
# Total params: 20,026,949
# Trainable params: 2,565
# Non-trainable params: 20,024,384
# _________________________________________________________________
# Summary Report:  None

# %% [markdown]
# According to the above experiment results, if the task is **multi-label classification**, we need to set-up:
#
# * true (actual) labels encoding = **multi-hot vector**
#
# * activation = **sigmoid**
#
# * loss = **BinaryCrossentropy()**
#
# * accuracy metric= **BinaryAccuracy()**

# %% [markdown]
# ## JUSTIFICATION - REDUCE TIME COMPLEXITIES

# %% [markdown]
# Low complexity encoder:
#              Use of low complexity encoder in the input layer to resize and scale the images so that we can save time in training, testing, fitting data models.
#
# Parallel processing:
#             The value tf.data.AUTOTUNE means that TensorFlow will dynamically adjust the number of parallel calls to maximize the performance which includes in reducing time complexity to get desired outcome
#
# Data sampling:
#            If the dataset is very large, you can use random sampling techniques to reduce the size of the data, and hence, the time complexity of the classification process.
#
# Early Stopping:
#            By monitoring the performance of the classifier on a validation set and stopping the training process once the performance reaches a satisfactory level, the time complexity can be reduced.

# %% [markdown]
# ## REFERENCES
#
# [ Keras API reference / Losses / Probabilistic losses](https://keras.io/api/losses/probabilistic_losses/
# )
#
# [Keras API reference / Layers API / Layer activation functions](https://keras.io/api/layers/activations/)
#
# [Build TensorFlow input pipelines](https://www.tensorflow.org/guide/data#using_tfdata_with_tfkeras)
#
# [TensorFlow - SparseCategoricalCrossentropy](https://stackoverflow.com/questions/59787897/how-does-tensorflow-sparsecategoricalcrossentropy-work)
#
#
# [Cross-entropy vs sparse-cross-entropy](https://stats.stackexchange.com/questions/326065/cross-entropy-vs-sparse-cross-entropy-when-to-use-one-over-the-other)
#
# [Binary_crossentropy and categorical_crossentropy - different performance](https://stackoverflow.com/questions/42081257/why-binary-crossentropy-and-categorical-crossentropy-give-different-performances)
